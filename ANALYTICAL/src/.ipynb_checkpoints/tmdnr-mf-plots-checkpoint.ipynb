# %%
import numpy as np
import os
import copy
import warnings

import matplotlib.pyplot as plt
from matplotlib import rcParams
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Arial']
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
import seaborn as sns
sns.set()
sns.set_style("white")
sns.set_palette(sns.diverging_palette(220, 20, n=6))

# %% [markdown]
# # Load data from local files or from hard drive?

# %%
localData = False

# %%
nOrb = 3

Nx = 512
Ny = 16
beta = 100
U = 14
initCond = 1

if localData == False:
    
    ## LOAD FILES FROM HARD DRIVE (THEY ARE TOO BIG!). SET PATH BELOW.
    
    ADATA = "ADATA HD710"
    Flash = "Francisco's Flash Drive"

    SAVEDIR = "../../../../../../../Volumes/" + ADATA + "/MScData/MeanFieldTMDnanoribbon/"
    #SAVEDIR = "../../../../../../../Volumes/" + Flash + "/MScData/MeanFieldTMDnanoribbon/"
    
    LOADSUBDIR = SAVEDIR + "Nx=" + str(Nx) +\
        "_Ny=" + str(Ny) + "_U=" + str(U) + "_beta=" + str(beta) + "/"
    
else:
    SAVEDIR = "../plots/MeanFieldTMDnanoribbon/"
    LOADSUBDIR = SAVEDIR + "Nx=" + str(Nx) +\
        "_Ny=" + str(Ny) + "_U=" + str(U) + "_beta=" + str(beta) + "/"

SAVESUBDIR = "../plots/MeanFieldTMDnanoribbon/" + "Nx=" + str(Nx) +\
        "_Ny=" + str(Ny) + "_U=" + str(U) + "_beta=" + str(beta) + "/"
    
if not os.path.exists(SAVESUBDIR):
    os.makedirs(SAVESUBDIR)

# %%
nUp = np.loadtxt(LOADSUBDIR + "nUp.txt")
nDown = np.loadtxt(LOADSUBDIR + "nDown.txt")
eUp = np.loadtxt(LOADSUBDIR + "eUp.txt")
eDown = np.loadtxt(LOADSUBDIR + "eDown.txt")
wUp = np.loadtxt(LOADSUBDIR + "wUp.txt").reshape(Nx, nOrb * Ny, nOrb * Ny)
wDown = np.loadtxt(LOADSUBDIR + "wDown.txt").reshape(Nx, nOrb * Ny, nOrb * Ny)
itSwitch = int(np.loadtxt(LOADSUBDIR + "itSwitch_lastIt_mu.txt")[0])
lastIt = int(np.loadtxt(LOADSUBDIR + "itSwitch_lastIt_mu.txt")[1])
mu = np.loadtxt(LOADSUBDIR + "itSwitch_lastIt_mu.txt")[2]
energies = np.loadtxt(LOADSUBDIR + "energies.txt")

modelParams = np.loadtxt(LOADSUBDIR + "modelParams.txt")
abs_t0 = modelParams[0]
e1 = modelParams[1]
e2 = modelParams[2]
t0 = modelParams[3]
t1 = modelParams[4]
t2 = modelParams[5]
t11 = modelParams[6]
t12 = modelParams[7]
t22 = modelParams[8]

# %% [markdown]
# ## Band structure

# %%
sns.set_style("whitegrid")
ks = np.linspace(-np.pi,np.pi, num=Nx, endpoint=False)
plt.figure(1, figsize=(8, 6))
plt.plot(ks, abs_t0*eUp, markersize=2, linewidth = 0.5, c = 'r', label = r'$\uparrow$')
plt.plot(ks, abs_t0*eDown, markersize=2, linewidth = 0.5, c = 'b', label = r'$\downarrow$')
plt.plot(ks, abs_t0*np.ones(Nx)*mu, c = 'seagreen', linewidth = 1, label = r'$\varepsilon_F$')
plt.xlabel(r'$k$')
plt.ylabel(r'$\varepsilon_{k, \sigma}$')
plt.legend(bbox_to_anchor=(1,1))
plt.savefig(SAVESUBDIR + "bands_Nx=" + str(Nx) +\
            "_Ny=" + str(Ny) + "_U=" + str(U) + "_beta=" + str(beta)\
            + ".png", dpi = 500, bbox_inches='tight')

# %%
sns.set_style("whitegrid")
ks = np.linspace(-np.pi,np.pi, num=Nx, endpoint=False)
plt.figure(1, figsize=(8, 6))
plt.plot(ks, abs_t0*eUp, markersize=2, linewidth = 0.5, c = 'r', label = r'$\uparrow$')
plt.plot(ks, abs_t0*eDown, markersize=2, linewidth = 0.5, c = 'b', label = r'$\downarrow$')
plt.plot(ks, abs_t0*np.ones(Nx)*mu, c = 'seagreen', linewidth = 1, label = r'$\varepsilon_F$')
plt.xlabel(r'$k$')
plt.ylabel(r'$\varepsilon_{k, \sigma}$')
plt.ylim(1.95, 1.99)
plt.xlim(-1.74, -1.72)
plt.legend(bbox_to_anchor=(1,1))
plt.savefig(SAVESUBDIR + "/zoomed_atBandCrossing_bands_Nx=" + str(Nx) +\
            "_Ny=" + str(Ny) + "_U=" + str(U) + "_beta=" + str(beta)\
            + ".png", dpi = 500, bbox_inches='tight')

# %%
sns.set_style("whitegrid")
ks = np.linspace(-np.pi,np.pi, num=Nx, endpoint=False)
plt.figure(1, figsize=(8, 6))
plt.plot(ks, abs_t0*eUp, markersize=2, linewidth = 0.5, c = 'r', label = r'$\uparrow$')
plt.plot(ks, abs_t0*eDown, markersize=2, linewidth = 0.5, c = 'b', label = r'$\downarrow$')
plt.plot(ks, abs_t0*np.ones(Nx)*mu, c = 'seagreen', linewidth = 1, label = r'$\varepsilon_F$')
plt.xlabel(r'$k$')
plt.ylabel(r'$\varepsilon_{k, \sigma}$')
plt.ylim(1, 2.8)
plt.xlim(-2.6, -2.1)
plt.legend(loc = 4)
plt.savefig(SAVESUBDIR + "/zoomed_atK_bands_Nx=" + str(Nx) +\
            "_Ny=" + str(Ny) + "_U=" + str(U) + "_beta=" + str(beta)\
            + ".png", dpi = 500, bbox_inches='tight')

# %% [markdown]
# ## Magnetization

# %%
sns.set_style("white")
nUpSite = np.zeros(Ny)
nDownSite = np.zeros(Ny)
for i in range(Ny):    
    nUpSite[i] = nUp[nOrb * i] + nUp[nOrb * i + 1] + nUp[nOrb * i + 2]
    nDownSite[i] = nDown[nOrb * i] + nDown[nOrb * i + 1] + nDown[nOrb * i + 2]
    
plt.plot((nUpSite-nDownSite), markersize=4, linewidth = 0.5, c = 'r', marker = 'o')
plt.ylabel(r'$\left\langle m_y \right\rangle$')
plt.xlabel(r'$y$')
plt.savefig(SAVESUBDIR + "/magProf_Nx=" + str(Nx) +\
            "_Ny=" + str(Ny) + "_U=" + str(U) + "_beta=" + str(beta)\
            + ".png", dpi = 500, bbox_inches='tight')

# %% [markdown]
# ## Grandpotential minimization

# %%
lastNit = 5

fig = plt.figure(1)
ax = fig.add_subplot(111)
ax.plot(np.arange(energies[itSwitch:lastIt].size) + itSwitch,\
        energies[itSwitch:lastIt], color = "#e74c3c", linewidth = 1)
plt.xlabel('Iteration')
plt.ylabel(r'$\Omega$')
plt.xlim(itSwitch, lastIt+35)
axins1 = inset_axes(ax, width=1.5, height=1., loc=1)
axins2 = inset_axes(ax, width=1.5, height=1., loc=4)
axins1.set_xlabel('Iteration')
axins1.set_ylabel(r'$\Omega$')
axins1.plot(np.arange(energies[:lastIt].size),\
            energies[:lastIt], color = "#e74c3c", linewidth = 1)
axins2.plot(np.arange(energies[lastIt-lastNit:lastIt].size) + (lastIt - lastNit)\
            , energies[lastIt-lastNit:lastIt], color = "#e74c3c", linewidth = 1)
axins2.tick_params(labelbottom=False)

plt.savefig(SAVESUBDIR + "/grandpotMin_Nx=" + str(Nx) +\
            "_Ny=" + str(Ny) + "_U=" + str(U) + "_beta=" + str(beta)\
            + ".png", dpi = 500, bbox_inches='tight')

# %% [markdown]
# ## Represent the result on the lattice

# %%
dotscale = 30

longLength = 20

clr = np.chararray((longLength * Ny), itemsize = 10)
        
a1 = np.arange(longLength)
a2 = np.arange(Ny)
vs = np.zeros((longLength * Ny , 2))
lat = np.zeros((longLength * Ny))
v1 = 4*np.array([1, 0])
v2 = 4*np.array([1 / 2, np.sqrt(3) / 2])
for i in range(longLength):
    for j in range(Ny):
            vs[longLength * j + i, :] = \
            a1[i] * v1 + a2[j] * v2 
            lat[longLength * j + i] \
            =  dotscale * longLength * (nUpSite[j]\
                           - nDownSite[j] )
            if (nUpSite[j]\
                - nDownSite[j] ) < 0 :
                clr[longLength * j + i] = "#95a5a6"
            else:
                clr[longLength * j + i] = "#e74c3c"

fig = plt.figure(1, figsize=(10, 10))
ax = fig.add_subplot(111)
ax.scatter(vs[:, 0], vs[:, 1], s = abs(lat), c = clr.decode('UTF-8'), alpha = 0.8, edgecolors = None)
ax.axis('equal')
ax.set_yticklabels([])
ax.set_xticklabels([])

plt.savefig(SAVESUBDIR + "/lattice_Nx=" + str(Nx) +\
            "_Ny=" + str(Ny) + "_U=" + str(U) + "_beta=" + str(beta) + ".png", dpi = 600)

# %% [markdown]
# ## Wavefunctions

# %% [markdown]
# ### Near the K point

# %%
sns.set_style("white")

ks = np.linspace(-np.pi, np.pi, num=Nx, endpoint=False)

## Find the index(es) of the K point

Kpoint = -2.35
Ktol = 0.008
idxK = np.where(np.isclose(ks, Kpoint, atol=Ktol) == True)[0][0]
print(idxK)

## Find the index of the edge band
Eedge = 1.45
Etol= 0.1
idxE = np.where(np.isclose(eUp[idxK, :] * abs_t0, Eedge, atol=Etol) == True)[0][0]
print(idxE)

## Fill lists

statesUp = wUp[idxE, :, :]
statesDown = wDown[idxE, :, :]

dz2Up = np.zeros(Ny)
dxyUp = np.zeros(Ny)
dx2y2Up = np.zeros(Ny)

dz2Dw = np.zeros(Ny)
dxyDw = np.zeros(Ny)
dx2y2Dw = np.zeros((Ny))

for i in range(Ny):
    dz2Up[i] = statesUp[nOrb * i, idxE]
    dxyUp[i] = statesUp[nOrb * i + 1, idxE]
    dx2y2Up[i] = statesUp[nOrb * i + 2, idxE]
    dz2Dw[i] = statesUp[nOrb * i, idxE]
    dxyDw[i] = statesUp[nOrb * i + 1, idxE]
    dx2y2Dw[i] = statesUp[nOrb * i + 2, idxE]
    
plt.figure(1)
plt.plot(dz2Up, \
         label = \
         r'$|\left\langle \psi^{d_{z^2}}_{K, \sigma} (y) | \psi^{d_{z^2}}_{K, \sigma} (\varepsilon = \varepsilon_{K} \right\rangle|^2$',\
        linewidth = 0.7, marker = 'o', markersize = 4,
        )
plt.plot(dxyUp, \
        label = \
         r'$|\left\langle \psi^{d_{xy}}_{K, \sigma, y} | \psi^{d_{xy}}_{K, \sigma} (\varepsilon = \varepsilon_{K} \right\rangle|^2$',\
        linewidth = 0.7, marker = 'o', markersize = 4)
plt.plot(dx2y2Up, \
        label = \
         r'$|\left\langle \psi^{d_{x^2 - y^2}}_{K, \sigma, y} | \psi^{d_{x^2 - y^2}}_{K, \sigma} (\varepsilon = \varepsilon_{K} \right\rangle|^2$',\
        linewidth = 0.7, marker = 'o', markersize = 4)
plt.xlabel(r'$y$')
plt.ylabel(r'$|\left\langle \psi_{K, \sigma}(y) | \psi_{K, \sigma} (\varepsilon = \varepsilon_{K}) \right\rangle|^2$')
plt.legend()
plt.savefig(SAVESUBDIR + "wfAroundK_" + str(Kpoint) +"_Up_Nx=" + str(Nx) +\
            "_Ny=" + str(Ny) + "_U=" + str(U) + "_beta=" + str(beta) + ".png", dpi = 600)
# Out:
# 64
# 15

# %% [markdown]
# ### A bit to the right

# %%
sns.set_style("white")

ks = np.linspace(-np.pi, np.pi, num=Nx, endpoint=False)

## Find the index(es) of the K point

Kpoint = -1.73
Ktol = 0.008
idxK = np.where(np.isclose(ks, Kpoint, atol=Ktol) == True)[0][0]
print(idxK)

## Find the index of the edge band
Eedge = 1.97
Etol= 0.1
idxE = np.where(np.isclose(eUp[idxK, :] * abs_t0, Eedge, atol=Etol) == True)[0][0]
print(idxE)

## Fill lists

statesUp = wUp[idxE, :, :]
statesDown = wDown[idxE, :, :]

dz2Up = np.zeros(Ny)
dxyUp = np.zeros(Ny)
dx2y2Up = np.zeros(Ny)

dz2Dw = np.zeros(Ny)
dxyDw = np.zeros(Ny)
dx2y2Dw = np.zeros((Ny))

for i in range(Ny):
    dz2Up[i] = statesUp[nOrb * i, idxE]
    dxyUp[i] = statesUp[nOrb * i + 1, idxE]
    dx2y2Up[i] = statesUp[nOrb * i + 2, idxE]
    dz2Dw[i] = statesUp[nOrb * i, idxE]
    dxyDw[i] = statesUp[nOrb * i + 1, idxE]
    dx2y2Dw[i] = statesUp[nOrb * i + 2, idxE]
    
plt.figure(1)
plt.plot(dz2Up, \
         label = \
         r'$|\left\langle \psi^{d_{z^2}}_{k_{cross}, \sigma} (y) | \psi^{d_{z^2}}_{k_{cross}, \sigma} (\varepsilon = \varepsilon_{cross} \right\rangle|^2$',\
        linewidth = 0.7, marker = 'o', markersize = 4)
plt.plot(dxyUp, \
        label = \
         r'$|\left\langle \psi^{d_{xy}}_{k_{cross}, \sigma, y} | \psi^{d_{xy}}_{k_{cross}, \sigma} (\varepsilon = \varepsilon_{cross} \right\rangle|^2$',\
        linewidth = 0.7, marker = 'o', markersize = 4)
plt.plot(dx2y2Up, \
        label = \
         r'$|\left\langle \psi^{d_{x^2 - y^2}}_{k_{cross}, \sigma, y} | \psi^{d_{x^2 - y^2}}_{k_{cross}, \sigma} (\varepsilon = \varepsilon_{cross} \right\rangle|^2$',\
        linewidth = 0.7, marker = 'o', markersize = 4)
plt.xlabel(r'$y$')
plt.ylabel(r'$|\left\langle \psi_{k_{cross}, \sigma}(y) | \psi_{k_{cross}, \sigma} (\varepsilon = \varepsilon_{cross}) \right\rangle|^2$')
plt.legend()
plt.savefig(SAVESUBDIR + "wfAroundK_" + str(Kpoint) +"_Nx=" + str(Nx) +\
            "_Ny=" + str(Ny) + "_U=" + str(U) + "_beta=" + str(beta) + ".png", dpi = 600)
# Out:
# 115
# 16

# %% [markdown]
# ### A bit more

# %%
sns.set_style("white")

ks = np.linspace(-np.pi, np.pi, num=Nx, endpoint=False)

## Find the index(es) of the K point

Kpoint = 1.73
Ktol = 0.008
idxK = np.where(np.isclose(ks, Kpoint, atol=Ktol) == True)[0][0]
print(idxK)

## Find the index of the edge band
Eedge = 1.97
Etol= 0.1
idxE = np.where(np.isclose(eUp[idxK, :] * abs_t0, Eedge, atol=Etol) == True)[0][0]
print(idxE)

## Fill lists

statesUp = wUp[idxE, :, :]
statesDown = wDown[idxE, :, :]

dz2Up = np.zeros(Ny)
dxyUp = np.zeros(Ny)
dx2y2Up = np.zeros(Ny)

dz2Dw = np.zeros(Ny)
dxyDw = np.zeros(Ny)
dx2y2Dw = np.zeros((Ny))

for i in range(Ny):
    dz2Up[i] = statesUp[nOrb * i, idxE]
    dxyUp[i] = statesUp[nOrb * i + 1, idxE]
    dx2y2Up[i] = statesUp[nOrb * i + 2, idxE]
    dz2Dw[i] = statesUp[nOrb * i, idxE]
    dxyDw[i] = statesUp[nOrb * i + 1, idxE]
    dx2y2Dw[i] = statesUp[nOrb * i + 2, idxE]
    
plt.figure(1)
plt.plot(dz2Up, \
         label = \
         r'$|\left\langle \psi^{d_{z^2}}_{K, \uparrow} (y) | \psi^{d_{z^2}}_{K, \uparrow} (\varepsilon = \varepsilon_{edge} \right\rangle|^2$',\
        linewidth = 0.7, marker = 'o', markersize = 4)
plt.plot(dxyUp, \
        label = \
         r'$|\left\langle \psi^{d_{xy}}_{K, \uparrow, y} | \psi^{d_{xy}}_{K, \uparrow} (\varepsilon = \varepsilon_{edge} \right\rangle|^2$',\
        linewidth = 0.7, marker = 'o', markersize = 4)
plt.plot(dx2y2Up, \
        label = \
         r'$|\left\langle \psi^{d_{x^2 - y^2}}_{K, \uparrow, y} | \psi^{d_{x^2 - y^2}}_{K, \uparrow} (\varepsilon = \varepsilon_{edge} \right\rangle|^2$',\
        linewidth = 0.7, marker = 'o', markersize = 4)
plt.xlabel(r'$y$')
plt.ylabel(r'$|\left\langle \psi_{K, \uparrow}(y) | \psi_{K, \uparrow} (\varepsilon = \varepsilon_{edge}) \right\rangle|^2$')
plt.legend()
plt.savefig(SAVESUBDIR + "wfAroundK_" + str(Kpoint) +"_Up_Nx=" + str(Nx) +\
            "_Ny=" + str(Ny) + "_U=" + str(U) + "_beta=" + str(beta) + ".png", dpi = 600)

plt.figure(2)
plt.plot(dz2Dw, \
         label = \
         r'$|\left\langle \psi^{d_{z^2}}_{K, \downarrow, y} | \psi^{d_{z^2}}_{K, \downarrow} (\varepsilon = \varepsilon_{edge} \right\rangle|^2$',\
        linewidth = 0.7, marker = 'o', markersize = 4)
plt.plot(dxyDw, \
        label = \
         r'$|\left\langle \psi^{d_{xy}}_{K, \downarrow, y} | \psi^{d_{xy}}_{K, \downarrow} (\varepsilon = \varepsilon_{edge} \right\rangle|^2$',\
        linewidth = 0.7, marker = 'o', markersize = 4)
plt.plot(dx2y2Dw, \
        label = \
         r'$|\left\langle \psi^{d_{x^2 - y^2}}_{K, \downarrow, y} | \psi^{d_{x^2 - y^2}}_{K, \downarrow, \varepsilon_{edge}} \right\rangle|^2$',\
        linewidth = 0.7, marker = 'o', markersize = 4)
plt.xlabel(r'$y$')
plt.ylabel(r'$|\left\langle \psi_{K, \downarrow}(y) | \psi_{K, \uparrow} (\varepsilon = \varepsilon_{edge}) \right\rangle|^2$')
plt.legend()
plt.savefig(SAVESUBDIR + "wfAroundK"+ str(Kpoint) +"_Dw_Nx=" + str(Nx) +\
            "_Ny=" + str(Ny) + "_U=" + str(U) + "_beta=" + str(beta) + ".png", dpi = 600)
# Out:
# 397
# 16

# %%
sns.set_style("white")

ks = np.linspace(-np.pi, np.pi, num=Nx, endpoint=False)

## Find the index(es) of the K point

Kpoint = -1.73
Ktol = 0.008
idxK = np.where(np.isclose(ks, Kpoint, atol=Ktol) == True)[0][0]
print(idxK)

## Find the index of the edge band
Eedge = 1.97
Etol= 0.1
idxE = np.where(np.isclose(eUp[idxK, :] * abs_t0, Eedge, atol=Etol) == True)[0][0]
print(idxE)

## Fill lists

statesUp = wUp[idxE, :, :]
statesDown = wDown[idxE, :, :]

dz2Up = np.zeros(Ny)
dxyUp = np.zeros(Ny)
dx2y2Up = np.zeros(Ny)

dz2Dw = np.zeros(Ny)
dxyDw = np.zeros(Ny)
dx2y2Dw = np.zeros((Ny))

for i in range(Ny):
    dz2Up[i] = statesUp[nOrb * i, idxE]
    dxyUp[i] = statesUp[nOrb * i + 1, idxE]
    dx2y2Up[i] = statesUp[nOrb * i + 2, idxE]
    dz2Dw[i] = statesUp[nOrb * i, idxE]
    dxyDw[i] = statesUp[nOrb * i + 1, idxE]
    dx2y2Dw[i] = statesUp[nOrb * i + 2, idxE]
    
plt.figure(1)
plt.plot(dz2Up, \
         label = \
         r'$|\left\langle \psi^{d_{z^2}}_{K, \uparrow} (y) | \psi^{d_{z^2}}_{K, \uparrow} (\varepsilon = \varepsilon_{edge} \right\rangle|^2$',\
        linewidth = 0.7, marker = 'o', markersize = 4)
plt.plot(dxyUp, \
        label = \
         r'$|\left\langle \psi^{d_{xy}}_{K, \uparrow, y} | \psi^{d_{xy}}_{K, \uparrow} (\varepsilon = \varepsilon_{edge} \right\rangle|^2$',\
        linewidth = 0.7, marker = 'o', markersize = 4)
plt.plot(dx2y2Up, \
        label = \
         r'$|\left\langle \psi^{d_{x^2 - y^2}}_{K, \uparrow, y} | \psi^{d_{x^2 - y^2}}_{K, \uparrow} (\varepsilon = \varepsilon_{edge} \right\rangle|^2$',\
        linewidth = 0.7, marker = 'o', markersize = 4)
plt.xlabel(r'$y$')
plt.ylabel(r'$|\left\langle \psi_{K, \uparrow}(y) | \psi_{K, \uparrow} (\varepsilon = \varepsilon_{edge}) \right\rangle|^2$')
plt.legend()
plt.savefig(SAVESUBDIR + "wfAroundK_" + str(Kpoint) +"_Up_Nx=" + str(Nx) +\
            "_Ny=" + str(Ny) + "_U=" + str(U) + "_beta=" + str(beta) + ".png", dpi = 600)

plt.figure(2)
plt.plot(dz2Dw, \
         label = \
         r'$|\left\langle \psi^{d_{z^2}}_{K, \downarrow, y} | \psi^{d_{z^2}}_{K, \downarrow} (\varepsilon = \varepsilon_{edge} \right\rangle|^2$',\
        linewidth = 0.7, marker = 'o', markersize = 4)
plt.plot(dxyDw, \
        label = \
         r'$|\left\langle \psi^{d_{xy}}_{K, \downarrow, y} | \psi^{d_{xy}}_{K, \downarrow} (\varepsilon = \varepsilon_{edge} \right\rangle|^2$',\
        linewidth = 0.7, marker = 'o', markersize = 4)
plt.plot(dx2y2Dw, \
        label = \
         r'$|\left\langle \psi^{d_{x^2 - y^2}}_{K, \downarrow, y} | \psi^{d_{x^2 - y^2}}_{K, \downarrow, \varepsilon_{edge}} \right\rangle|^2$',\
        linewidth = 0.7, marker = 'o', markersize = 4)
plt.xlabel(r'$y$')
plt.ylabel(r'$|\left\langle \psi_{K, \downarrow}(y) | \psi_{K, \uparrow} (\varepsilon = \varepsilon_{edge}) \right\rangle|^2$')
plt.legend()
plt.savefig(SAVESUBDIR + "wfAroundK"+ str(Kpoint) +"_Dw_Nx=" + str(Nx) +\
            "_Ny=" + str(Ny) + "_U=" + str(U) + "_beta=" + str(beta) + ".png", dpi = 600)
